# %% [markdown]
# <a href="https://colab.research.google.com/github/Sam-Ayodeji/Pneumonia_Detection_Hamoye_StoryBoard/blob/main/HamoyeDSI_PneumoniaDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget https://www.dropbox.com/s/tlxserrdhe240lu/archive.zip
# Out:
# --2024-05-09 14:57:51--  https://www.dropbox.com/s/tlxserrdhe240lu/archive.zip
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.80.18, 2620:100:6035:18::a27d:5512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.80.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /s/raw/tlxserrdhe240lu/archive.zip [following]
# --2024-05-09 14:57:52--  https://www.dropbox.com/s/raw/tlxserrdhe240lu/archive.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uced8141f6e335328b42236a1a45.dl.dropboxusercontent.com/cd/0/inline/CSn4yLwonDpp1eobiyV_wwk1ujeGGMxGWYdrXS7dZe2m3mUmzLsksUMtmYnyhfftftDvIdinPRhA-dQn0oqXzN-rnYGkZwwXxH8YmRArp3fB07lMdOfHxP98Ld9IuRbPeAamdCVbBkvdQY51hDvqd7S7/file# [following]
# --2024-05-09 14:57:52--  https://uced8141f6e335328b42236a1a45.dl.dropboxusercontent.com/cd/0/inline/CSn4yLwonDpp1eobiyV_wwk1ujeGGMxGWYdrXS7dZe2m3mUmzLsksUMtmYnyhfftftDvIdinPRhA-dQn0oqXzN-rnYGkZwwXxH8YmRArp3fB07lMdOfHxP98Ld9IuRbPeAamdCVbBkvdQY51hDvqd7S7/file
# Resolving uced8141f6e335328b42236a1a45.dl.dropboxusercontent.com (uced8141f6e335328b42236a1a45.dl.dropboxusercontent.com)... 162.125.80.15, 2620:100:6035:15::a27d:550f
# Connecting to uced8141f6e335328b42236a1a45.dl.dropboxusercontent.com (uced8141f6e335328b42236a1a45.dl.dropboxusercontent.com)|162.125.80.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/CSkJKUX6MBvD2Tx3bK1witgjMZTk3XQBs53w1V5P8QjeWnoNuoTpTN-j965NgTQ0oie5acbUzv4czJJozy71o1_XjIxRNfexuJukLmYCZPDW77GV-iegPIwS88mtTWD5fogNAP6vvKvpDdFChgE503l74BUpiZ2KCH3jByegixELqll9i0lPiTxqlX7SZuF_YvoCZ0fu5e3wv1UhA3bxwcatU7wnqROtAEgK6WAKUDU-v0h5xvtPk1p6COWL36R8q9yaQbZTLlnBSKqUuRx79Q5gRe1vP6FLiJwza8QnI2AYV-5BcudhwYAgq_cVB_OzPtygRn-m6dOS1un3Ykkadk5MDSVEtHBzmLm2mmmxM5CexAT2xiaT6m_EoNOWVd2uWU0/file [following]
# --2024-05-09 14:57:53--  https://uced8141f6e335328b42236a1a45.dl.dropboxusercontent.com/cd/0/inline2/CSkJKUX6MBvD2Tx3bK1witgjMZTk3XQBs53w1V5P8QjeWnoNuoTpTN-j965NgTQ0oie5acbUzv4czJJozy71o1_XjIxRNfexuJukLmYCZPDW77GV-iegPIwS88mtTWD5fogNAP6vvKvpDdFChgE503l74BUpiZ2KCH3jByegixELqll9i0lPiTxqlX7SZuF_YvoCZ0fu5e3wv1UhA3bxwcatU7wnqROtAEgK6WAKUDU-v0h5xvtPk1p6COWL36R8q9yaQbZTLlnBSKqUuRx79Q5gRe1vP6FLiJwza8QnI2AYV-5BcudhwYAgq_cVB_OzPtygRn-m6dOS1un3Ykkadk5MDSVEtHBzmLm2mmmxM5CexAT2xiaT6m_EoNOWVd2uWU0/file
# Reusing existing connection to uced8141f6e335328b42236a1a45.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1237072214 (1.2G) [application/zip]
# Saving to: ‘archive.zip.1’
#
# archive.zip.1       100%[===================>]   1.15G  28.6MB/s    in 41s
#
# 2024-05-09 14:58:34 (28.6 MB/s) - ‘archive.zip.1’ saved [1237072214/1237072214]

# %%
# !unzip -q "archive.zip"

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

tf.random.set_seed(42)

# %%
# Creating the Pathlib PATH objects
train_path= Path("chest_xray/train/")
test_path= Path("chest_xray/test")
valid_path= Path("chest_xray/val")

# %%
"""Accessing all the files inside the "Normal" and "Pneumonia" folders of the above paths
(returns all files that are two layers below the path)"""
train_image_paths = train_path.glob("*/*")
val_image_paths = valid_path.glob("*/*")

# The output is a generator object
print(train_image_paths)
# Out:
# <generator object Path.glob at 0x7820ba50b0d0>

# %%
# Converting the generator object to a list of elements (the outputs are PosiPath objects)
train_image_paths = list(train_image_paths)
val_image_paths = list(val_image_paths)

print(train_image_paths[:6])
# Out:
# [PosixPath('chest_xray/train/NORMAL/NORMAL2-IM-1164-0001.jpeg'), PosixPath('chest_xray/train/NORMAL/IM-0525-0001-0001.jpeg'), PosixPath('chest_xray/train/NORMAL/NORMAL2-IM-1102-0001-0001.jpeg'), PosixPath('chest_xray/train/NORMAL/NORMAL2-IM-0480-0001.jpeg'), PosixPath('chest_xray/train/NORMAL/IM-0131-0001.jpeg'), PosixPath('chest_xray/train/NORMAL/IM-0290-0001.jpeg')]

# %%
# Converting the paths from PosiPath objects to strings
train_image_paths = list(map(lambda x: str(x), train_image_paths))
val_image_paths = list(map(lambda x: str(x), val_image_paths))

print(train_image_paths[:6])
print(val_image_paths[:6])
# Out:
# ['chest_xray/train/NORMAL/NORMAL2-IM-1164-0001.jpeg', 'chest_xray/train/NORMAL/IM-0525-0001-0001.jpeg', 'chest_xray/train/NORMAL/NORMAL2-IM-1102-0001-0001.jpeg', 'chest_xray/train/NORMAL/NORMAL2-IM-0480-0001.jpeg', 'chest_xray/train/NORMAL/IM-0131-0001.jpeg', 'chest_xray/train/NORMAL/IM-0290-0001.jpeg']
# ['chest_xray/val/NORMAL/NORMAL2-IM-1440-0001.jpeg', 'chest_xray/val/NORMAL/NORMAL2-IM-1438-0001.jpeg', 'chest_xray/val/NORMAL/NORMAL2-IM-1437-0001.jpeg', 'chest_xray/val/NORMAL/NORMAL2-IM-1430-0001.jpeg', 'chest_xray/val/NORMAL/NORMAL2-IM-1436-0001.jpeg', 'chest_xray/val/NORMAL/NORMAL2-IM-1431-0001.jpeg']

# %%
# Store lengths of training and validation sets
train_length = len(train_image_paths)
val_length = len(val_image_paths)
print("training set length: ",train_length, ", validation set length: ", val_length)
# Out:
# training set length:  5216 , validation set length:  16

# %%
# Assigning labels to each class of images
labels ={"NORMAL":0, "PNEUMONIA":1}
inv_labels={0:"NORMAL", 1:"PNEUMONIA"}

def get_label(path : str) -> int:
  return labels[path.split("/")[-2]]

train_labels = list(map(lambda x: get_label(x), train_image_paths))
val_labels = list(map(lambda x: get_label(x), val_image_paths))

print(train_labels[:6])
# Out:
# [0, 0, 0, 0, 0, 0]

# %%
# Data transformation

BATCH_SIZE = 32

def load_and_transform(image, label, train= True):
  image = tf.io.read_file(image)
  image = tf.io.decode_jpeg(image, channels=3)
  image = tf.image.resize(image, [224, 224], method="nearest")
  if train:
    image = tf.image.random_flip_left_right(image)
    return image, label

# %%
# Creating a tensorflow data object

def get_dataset(paths, labels, train= True):
  image_paths = tf.convert_to_tensor(paths)
  labels = tf.convert_to_tensor(labels)

  image_dataset = tf.data.Dataset.from_tensor_slices(image_paths)
  label_dataset = tf.data.Dataset.from_tensor_slices(labels)

  dataset = tf.data.Dataset.zip((image_dataset, label_dataset)).shuffle(1000)

  dataset = dataset.map(lambda image, label: load_and_transform(image, label, train))
  dataset = dataset.repeat()
  dataset = dataset.shuffle(2048)
  dataset = dataset.batch(BATCH_SIZE)

  return dataset

# %%
# Testing the training data object
# %time train_dataset = get_dataset(train_image_paths, train_labels)
image, label = next(iter(train_dataset))
print(image.shape)
print(label.shape)
# Out:
# CPU times: user 1.42 s, sys: 302 ms, total: 1.72 s
# Wall time: 3.17 s
# (32, 224, 224, 3)
# (32,)

# %%
# Viewing a sample train image
print(inv_labels[label[0].numpy()])
plt.imshow(image[0].numpy().reshape(224, 224, 3))
# Out:
# NORMAL

# %%
# Testing the validation data object
# %time val_dataset = get_dataset(val_image_paths, val_labels)

image, label = next(iter(val_dataset))
print(image.shape)
print(label.shape)
# Out:
# CPU times: user 39.6 ms, sys: 974 µs, total: 40.6 ms
# Wall time: 46.9 ms
# (32, 224, 224, 3)
# (32,)

# %%
# Building ResNet50 model
from tensorflow.keras.applications import ResNet50V2

backbone = ResNet50V2(
    input_shape= (224, 224, 3),
    include_top= False
)
model = tf.keras.Sequential([
    backbone,
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(1, activation= "sigmoid")
])

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94668760/94668760 [==============================] - 4s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50v2 (Functional)     (None, 7, 7, 2048)        23564800
#
#  global_average_pooling2d (  (None, 2048)              0
#  GlobalAveragePooling2D)
#
#  dense (Dense)               (None, 1)                 2049
#
# =================================================================
# Total params: 23566849 (89.90 MB)
# Trainable params: 23521409 (89.73 MB)
# Non-trainable params: 45440 (177.50 KB)
# _________________________________________________________________

# %%
# Compiling the model by providing the optimizer, loss, and metrics
model.compile(
    optimizer = tf.keras.optimizers.Adam(learning_rate= 0.001, beta_1= 0.9,beta_2=0.999, epsilon=1e-07),
    loss= "binary_crossentropy",
    metrics=["accuracy", tf.keras.metrics.Precision(name="precision"),tf.keras.metrics.Recall(name="recall")]
)

# %%
# Defining Callbacks
checkpoint = tf.keras.callbacks.ModelCheckpoint("best_weight.h5",verbose=1, save_best_only=True, save_weights_only=True)
early_stop= tf.keras.callbacks.EarlyStopping(patience=4)

# %%
print(train_length//BATCH_SIZE)
print(val_length//BATCH_SIZE)
print(4//3)
print(train_length)
print(val_length)
# Out:
# 163
# 0
# 1
# 5216
# 16

# %%
# Training the model
history = model.fit(
    train_dataset,
    steps_per_epoch= train_length//BATCH_SIZE,
    epochs=8,
    callbacks=[checkpoint, early_stop],
    validation_data= val_dataset,
    #validation_steps= val_length//BATCH_SIZE
    validation_steps= 1
)
# Out:
# Epoch 1/8
# 163/163 [==============================] - ETA: 0s - loss: 0.1543 - accuracy: 0.9431 - precision: 0.9532 - recall: 0.9607
# Epoch 1: val_loss improved from inf to 13.23095, saving model to best_weight.h5
# 163/163 [==============================] - 131s 449ms/step - loss: 0.1543 - accuracy: 0.9431 - precision: 0.9532 - recall: 0.9607 - val_loss: 13.2309 - val_accuracy: 0.4375 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/8
# 163/163 [==============================] - ETA: 0s - loss: 0.0879 - accuracy: 0.9695 - precision: 0.9779 - recall: 0.9812
# Epoch 2: val_loss improved from 13.23095 to 0.88703, saving model to best_weight.h5
# 163/163 [==============================] - 72s 440ms/step - loss: 0.0879 - accuracy: 0.9695 - precision: 0.9779 - recall: 0.9812 - val_loss: 0.8870 - val_accuracy: 0.7188 - val_precision: 0.9000 - val_recall: 0.5294
# Epoch 3/8
# 163/163 [==============================] - ETA: 0s - loss: 0.0804 - accuracy: 0.9707 - precision: 0.9793 - recall: 0.9811
# Epoch 3: val_loss did not improve from 0.88703
# 163/163 [==============================] - 75s 463ms/step - loss: 0.0804 - accuracy: 0.9707 - precision: 0.9793 - recall: 0.9811 - val_loss: 11.8240 - val_accuracy: 0.5000 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/8
# 163/163 [==============================] - ETA: 0s - loss: 0.0891 - accuracy: 0.9664 - precision: 0.9772 - recall: 0.9775
# Epoch 4: val_loss did not improve from 0.88703
# 163/163 [==============================] - 75s 463ms/step - loss: 0.0891 - accuracy: 0.9664 - precision: 0.9772 - recall: 0.9775 - val_loss: 11.6843 - val_accuracy: 0.5312 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/8
# 163/163 [==============================] - ETA: 0s - loss: 0.0555 - accuracy: 0.9795 - precision: 0.9859 - recall: 0.9866
# Epoch 5: val_loss did not improve from 0.88703
# 163/163 [==============================] - 70s 430ms/step - loss: 0.0555 - accuracy: 0.9795 - precision: 0.9859 - recall: 0.9866 - val_loss: 1.3230 - val_accuracy: 0.5625 - val_precision: 0.7500 - val_recall: 0.1875
# Epoch 6/8
# 163/163 [==============================] - ETA: 0s - loss: 0.0491 - accuracy: 0.9810 - precision: 0.9868 - recall: 0.9876
# Epoch 6: val_loss improved from 0.88703 to 0.03927, saving model to best_weight.h5
# 163/163 [==============================] - 75s 464ms/step - loss: 0.0491 - accuracy: 0.9810 - precision: 0.9868 - recall: 0.9876 - val_loss: 0.0393 - val_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000
# Epoch 7/8
# 163/163 [==============================] - ETA: 0s - loss: 0.0437 - accuracy: 0.9831 - precision: 0.9882 - recall: 0.9892
# Epoch 7: val_loss did not improve from 0.03927
# 163/163 [==============================] - 75s 463ms/step - loss: 0.0437 - accuracy: 0.9831 - precision: 0.9882 - recall: 0.9892 - val_loss: 3.2556 - val_accuracy: 0.5000 - val_precision: 0.5000 - val_recall: 1.0000
# Epoch 8/8
# 163/163 [==============================] - ETA: 0s - loss: 0.0503 - accuracy: 0.9818 - precision: 0.9880 - recall: 0.9873
# Epoch 8: val_loss did not improve from 0.03927
# 163/163 [==============================] - 75s 461ms/step - loss: 0.0503 - accuracy: 0.9818 - precision: 0.9880 - recall: 0.9873 - val_loss: 3.9771 - val_accuracy: 0.5312 - val_precision: 0.5312 - val_recall: 1.0000

# %%
# Interpreting the model's metrics
fig, ax= plt.subplots(1,4, figsize=(20,3))
ax = ax.ravel()

for i, met in enumerate(["precision", "recall", "accuracy", "loss"]):
  ax[i].plot(history.history[met])
  ax[i].plot(history.history["val_"+ met])
  ax[i].set_title("Model {}".format(met))
  ax[i].set_xlabel("epochs")
  ax[i].set_ylabel(met)
  ax[i].legend(["train", "val"])

# %%
# Saving the best model
# Loading the best weights
model.load_weights("best_weight.h5")
# saving the model weights and architecture
model.save("model.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
loaded_model= tf.keras.models.load_model("model.h5")

# %%
# Creating a test dataset
test_image_paths = list(test_path.glob("*/*"))
test_image_paths = list(map(lambda x: str(x), test_image_paths))
test_labels = list(map(lambda x: get_label(x), test_image_paths))
test_image_paths = tf.convert_to_tensor(test_image_paths)
test_labels = tf.convert_to_tensor(test_labels)

def decode_image(image, label):
  image= tf.io.read_file(image)
  image= tf.io.decode_jpeg(image, channels=3)
  image= tf.image.resize(image, [224, 224], method="nearest")
  return image, label

test_dataset=(
    tf.data.Dataset.from_tensor_slices((test_image_paths, test_labels))
    .map(decode_image)
    .batch(BATCH_SIZE)
)

# %%
# Verifyiing the test dataset object
image, label = next(iter(test_dataset))
print(image.shape)
print(label.shape)
# Out:
# (32, 224, 224, 3)
# (32,)

# %%
# Viewing a sample validation image
print(inv_labels[label[0].numpy()])
plt.imshow(image[0].numpy().reshape(224,224,3))
# Out:
# NORMAL

# %%
# Evaluatiing the model on the test dataset
loss, acc, prec, rec= loaded_model.evaluate(test_dataset)

print("Testing accuracy: ", acc)
print("Testing precision: ", prec)
print("Testing recall: ", rec)
# Out:
# 20/20 [==============================] - 6s 241ms/step - loss: 1.0553 - accuracy: 0.8205 - precision: 0.7802 - recall: 0.9923
# Testing accuracy:  0.8205128312110901
# Testing precision:  0.7802419066429138
# Testing recall:  0.9923076629638672
